# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

data = pd.read_pickle("darklyrics/clustered_lyrics.pkl")
original_data = pd.read_pickle("darklyrics/data_filtered_original.pkl")
km = joblib.load('darklyrics/doc_cluster_big.pkl')
original_data.head()
# Out:
#                        album         artist                             name  \
# 3  Dissolve Into Nothingness  angara damana                      Blind Sheep
# 4  Dissolve Into Nothingness  angara damana  A New Age Of Darkness And Blood
# 5  Dissolve Into Nothingness  angara damana       Contradiction & Repetition
# 6  Dissolve Into Nothingness  angara damana       A Truth Hidden In The Womb
# 7  Dissolve Into Nothingness  angara damana                The Ado Of Wisdom
#
#    year                                             lyrics
# 3  2012  [Hopeless time Everything Falls Ideas Died One...
# 4  2012  [Somewhere Near An Empty Space, Where The Inau...
# 5  2012  [In This Endless Hedge, Where Is The Way Of Sa...
# 6  2012  [the troops of darkness fly high in the sky to...
# 7  2012  [I Am Standing In A Bright Circle, I See An Of...

# %%
# Build vocabulary of existing clusters
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words='english', min_df=25, max_df=0.5)
x = vectorizer.fit_transform(data['lyrics_string'])
vocabulary = vectorizer.get_feature_names()

# %%
# New data
initial_lyrics = """
behold the vast and formless black below surges the human maelstrom swarming worthless 
breaths asphyxiate in themselves churches drown beneath our skyscrapers 
quelled by a vicious elite
a glorious caste of true industry
no gods, no time, no life
zenith of the universe
and yet, nadir of hell
mesmerize, entrancing metropolis
black psychedelia"""

new_data = {
    "artist": "new",
    "cluster": 0,
    "cluster_labels": "",
    "x": 0,
    "y": 0
}

brackets_regex = re.compile('\[.*?\]')
apostrophe_regex = re.compile("[']")
punctuation_regex = re.compile('[^0-9a-zA-Z ]+')
double_space_regex = re.compile('\s+')

lyrics = initial_lyrics.lower()
lyrics = brackets_regex.sub("", lyrics)
lyrics = apostrophe_regex.sub("", lyrics)
lyrics = punctuation_regex.sub("", lyrics)
lyrics = double_space_regex.sub(" ", lyrics)

lyrics = lyrics.split()
lyrics = [word for word in lyrics if word in vocabulary]
lyrics = ' '.join(lyrics)

new_data['lyrics_string'] = lyrics
new_data = pd.DataFrame(new_data, index=[len(data)])
data = data.append(new_data)
data
# Out:
#                     artist  cluster  \
# 0                      '68        0
# 1               (sic)monic        1
# 2                      +\-       27
# 3          ...aaaarrghh...       18
# 4            ...and oceans       27
# 5                 .calibre       19
# 6                  .crrust        7
# 7               100 demons       25
# 8            1000 funerals       17
# 9     11 as in adversaries       21
# 10          11th dimension        7
# 11         122 stab wounds       19
# 12                13 faces       25
# 13              13 winters       27
# 14                    1349       16
# 15              13th draft        7
# 16                      16        4
# 17                 16 volt        7
# 18                    1956       19
# 19          2 times terror       19
# 20              25 ta life       22
# 21                  2cents       11
# 22             2nd suicide       27
# 23                     2x4        7
# 29    cant see way shame covering eyes carry flame m...  0.585339  0.328697
# ...                                                 ...       ...       ...
# 7404  body falling shot hate dead body love falling ... -0.751302 -0.247149
# 7405  opened eyes didnt see world anymore thought lo... -0.598369 -0.306544
# 7406  feel breath commands eyes beneath skin smile l... -0.289887 -0.333772
# 7407  time woke kiss tell time serious sell story on...  0.258095 -0.656182
# 7408  one guide us guide us place feel pain world bl...  0.675213 -0.244089
# 7409  stare stare eyes future bleak faith rebuild fa...  0.083104  0.057260
# 7410  freedom heart firmness soul play life signific... -0.464429  0.544600
# 7411  person climaxes die today marry prince gun han...  0.247529 -0.650047
# 7412  youth learned truth pure metal way glam rock s... -0.054896 -0.669477
# 7413  wake sound ringing ears bells toll midnight ho... -0.388840  0.521003
# 7414                                                    -0.838457 -0.156573
# 7415  imitate heroes emulate beliefs set standard se... -0.548264 -0.119004
# 7416  window pair big eyes watching bitch make love ...  0.280296 -0.722794
# 7417  bound rock hit scene hearts devoted metal rise... -0.491712 -0.401350
# 7418  came aiming judgment day fools false crusade b... -0.248839  0.001575
# 7419  afraid feel whats inside embrace soul solitude... -0.170872  0.072421
# 7420  conflagration bidden forth dying sun brilliant...  0.705434 -0.008296
# 7421  escape killers claws drain blood fed desire sa... -0.534902  0.290717
# 7422  gods building work society thougt london opium... -0.413674 -0.602312
# 7423  bled would choice youre still alive rejoice co...  0.207914 -0.511810
# 7424  falling ultimate depths desperation greed losi... -0.457643 -0.330221
# 7425  de evolution thousands years consolidates fear... -0.552790  0.287640
# 7426  even though walk valley shadow death crawling ... -0.395222  0.491889
# 7427  inn ert valhall ek helga nafn nn gef honum sin... -0.562783  0.627858
# 7428  torn two heavens weighing truths beyond sand b...  0.373226  0.582194
# 7429  alone ancient mountaintop stood one lost way w... -0.505631  0.227837
# 7430  penitent man pass anymore sinner shall perish ... -0.394436 -0.499350
# 7431  hear sirens sigh hopes misplaced hearts laid h...  0.627338 -0.317566
# 7432  recondite motives necessitate reform terrestri... -0.764456 -0.105708
# 7433  behold vast formless surges maelstrom swarming...  0.000000  0.000000
#
# [7434 rows x 6 columns]

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words='english', min_df=25, max_df=0.5)
x = vectorizer.fit_transform(data['lyrics_string'])
features = vectorizer.get_feature_names()
predictions = km.predict(x)
predictions
# Out:
# array([ 0,  1, 27, ..., 27, 19, 19], dtype=int32)

# %%
cluster = predictions[-1]
cluster_labels = data[data.cluster == cluster].iloc[0]['cluster_labels']
print cluster
print cluster_labels
# Out:
# 19
# shall fucking evil people eternal reality self existence gods escape shadows final control chaos stars minds destruction space endless future sea faith fuck void great grave sight suffering sorrow spirit

# %%
artist_sample = data[(data.cluster == cluster) & (data.artist != 'new')].sample(5)
artist_list = [row['artist'] for i, row in artist_sample.iterrows()]
print artist_list
song_sample = pd.DataFrame()
for i in range(0,5):
    song_sample = song_sample.append(original_data[original_data.artist == artist_list[i]].sample(1))
song_sample.head()
# Out:
# [u'kongh', u'the few against many', u'shen', u'godstomper', u'h\xe4vok \xfcnit']
#                                              album                artist  \
# 5911                                 Sole Creation                 kongh
# 54805                                          Sot  the few against many
# 39399                                       Shapes                  shen
# 18677  A Killer Combo (GODSTOMPER / MAGRUDERGRIND)            godstomper
# 11285            h.IV+ (Hoarse/Industrial/Viremia)            hävok ünit
#
#                                      name  year  \
# 5911                             Skymning  2013
# 54805                 One With The Shadow  2009
# 39399                  Downfall - Zaratan  2013
# 18677                       Family Crisis  2005
# 11285  Man vs. Flesh [Structured Suicide]  2007
#
#                                                   lyrics
# 5911   [Enclosed in a cloud shielding the outside off...
# 54805  [[Music by C. Älvestam, Lyrics by M. Stanne], ...
# 39399  [Craving power, never satisfied,, Island gaine...
# 18677  [Home life is a battleground, Tragedy to be fo...
# 11285  [Inside the void I will give myself control, I...

# %%
song_sample.iloc[1]['lyrics']
# Out:
# [u'[Music by C. \xc4lvestam, Lyrics by M. Stanne]',
#  u'It comes at you from both ends',
#  u'the narrowing splinter',
#  u'Of fading Life',
#  u'What comes of a fear so infinte',
#  u'In harrowing nights',
#  u'Of The Howling Dark',
#  u'It festers Inside your shadow',
#  u'Everpresent and overpowering',
#  u'This sickly fascination',
#  u'has become the last addiction',
#  u'The struggle continues',
#  u'with the detachment of lipe',
#  u'through proxy',
#  u'life has stepped back',
#  u'from a body in constant motion',
#  u'the shadows seen through',
#  u'transparent skin',
#  u'An apparition deep in those eyes',
#  u'So close you can taste it',
#  u'But is this all all you could ask for?',
#  u'Lay down your life',
#  u'The Power of death commands you',
#  u'The ultimate Lie',
#  u'The Power of death commands you',
#  u'Give in to the deal',
#  u'Become one with the Shadow',
#  u'It comes at you from both ends',
#  u'the narrowing splinter',
#  u'Of fading Life',
#  u'What comes of a fear so infinte',
#  u'In harrowing nights',
#  u'Of The Howling Dark',
#  u'It festers Inside your shadow',
#  u'Everpresent and overpowering',
#  u'This sickly fascination',
#  u'has become the last addiction',
#  u'The struggle contines',
#  u'Life has stepped back',
#  u'Transparent skin',
#  u'So close you can taste it',
#  u'The struggle continues',
#  u'with the detachment of lipe',
#  u'through proxy',
#  u'life has stepped back',
#  u'from a body in constant motion',
#  u'the shadows seen through',
#  u'transparent skin',
#  u'An apparition deep in those eyes',
#  u'So close you can taste it',
#  u'But is this all all you could ask for?',
#  u'Lay down your life',
#  u'The Power of death commands you',
#  u'The ultimate Lie',
#  u'The Power of death commands you',
#  u'Give in to the deal',
#  u'Become one with the Shadow']
