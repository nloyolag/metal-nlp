# %%
import pandas as pd
import numpy as np
import sklearn
import re
from sklearn.externals import joblib
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances

data = pd.read_pickle("darklyrics/clustered_lyrics.pkl")
original_data = pd.read_pickle("darklyrics/data_filtered_original.pkl")
km = joblib.load('darklyrics/doc_cluster_big.pkl')
original_data.head()
# Out:
#                        album         artist                             name  \
# 3  Dissolve Into Nothingness  angara damana                      Blind Sheep
# 4  Dissolve Into Nothingness  angara damana  A New Age Of Darkness And Blood
# 5  Dissolve Into Nothingness  angara damana       Contradiction & Repetition
# 6  Dissolve Into Nothingness  angara damana       A Truth Hidden In The Womb
# 7  Dissolve Into Nothingness  angara damana                The Ado Of Wisdom
#
#    year                                             lyrics
# 3  2012  [Hopeless time Everything Falls Ideas Died One...
# 4  2012  [Somewhere Near An Empty Space, Where The Inau...
# 5  2012  [In This Endless Hedge, Where Is The Way Of Sa...
# 6  2012  [the troops of darkness fly high in the sky to...
# 7  2012  [I Am Standing In A Bright Circle, I See An Of...

# %%
# Genre and Topic Tags

topic_labels = {
    0: "Gangster",
    1: "Fatalism",
    2: "Epic",
    3: "Sorrow",
    4: "Violence",
    5: "Satanic",
    6: "Imperial",
    7: "Getting Over",
    8: "Party",
    9: "Mythological",
    10: "Religious",
    11: "Breakup",
    12: "Gore",
    13: "Ancient Depravation",
    14: "Viking",
    15: "Murder",
    16: "Hell",
    17: "Medieval",
    18: "Runes",
    19: "Darkness",
    20: "Ancient",
    21: "Occultism",
    22: "Cursing",
    23: "Kingdom",
    24: "Pornographic",
    25: "Hate",
    26: "Polish",
    27: "Nature & Sadness",
    28: "Kings & Battles",
    29: "Rotten"
}

genre_labels = {
    0: "Glam Metal",
    1: "Thrash Metal",
    2: "Folk Metal",
    3: "Hard Rock",
    4: "Metalcore",
    5: "Black Metal",
    6: "Epic Doom Metal",
    7: "Metalcore",
    8: "Glam Metal",
    9: "Power Metal",
    10: "Christian Metal",
    11: "Nu Metal",
    12: "Brutal Death Metal",
    13: "Depressive Black Metal",
    14: "Viking Metal",
    15: "Grindcore",
    16: "Doom Metal",
    17: "Black Metal",
    18: "Foreign Metal",
    19: "Death Metal",
    20: "Speed Metal",
    21: "Doom Metal",
    22: "Grindcore",
    23: "Power Metal",
    24: "Goregrind",
    25: "Metalcore",
    26: "Polish Metal",
    27: "Gothic Metal",
    28: "Power Metal",
    29: "Death Metal"
}

# %%
# data['topic_label'] = data.apply(lambda x: topic_labels[x['cluster']], axis=1)
# data['genre_label'] = data.apply(lambda x: genre_labels[x['cluster']], axis=1)
# data = data.rename(columns={'cluster_labels': 'frequent_words'})
data['topic_label'] = data.topic_label.apply(lambda x: "Darkness" if (x == "Cosmic Horror") else x)
data
data.to_pickle('darklyrics/clustered_lyrics.pkl')

# %%
# Build vocabulary of existing clusters
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words='english', min_df=25, max_df=0.5)
x = vectorizer.fit_transform(data['lyrics_string'])
vocabulary = vectorizer.get_feature_names()

# %%
# New data
initial_lyrics = """
There was a time when legends of Crail ran true
All over, their majesty everyone knew
But now in the future, defeated by evil untold
We yearn for the knight from story of old

A hero cannot be defeated
Simply by making him die
Proletius will rise
A hologram hero will fight

Victorious eagle warfare
So glorious, riding high up in the sky
Victorious eagle warfare
Brave warriors questing hard until they die
With nothing above but the heavens above
Guiding us on through the war
Eagle force

Inside the chamber of cryogenetical fire
A magical wizard is doing a spell
Powered by robots, a hologram coming to life
To stand at the side of the king of Fife

The galaxy knights are rising
Reborn from the ashes of Crail
A force for the light
To whom we eternally hail

Victorious eagle warfare
So glorious, riding high up in the sky
Victorious eagle warfare
Brave warriors questing hard until they die
With nothing above but the heavens above
Guiding us on through the war
Eagle force

[Spoken:]
Mighty warriors of the galaxy
You have proven yourselves to be mighty indeed
Now, who of you will join me in my Space Knights of Crail?

Victorious eagle warfare
So glorious, riding high up in the sky
Victorious eagle warfare
Brave warriors questing hard until they die
With nothing above but the heavens above
Fight against power of evil corrupt
Guiding us on through the war
Eagle force
"""

new_data = {
    "artist": "new",
    "cluster": 0,
    "frequent_words": "",
    "x": 0,
    "y": 0,
    "genre_label": "",
    "topic_label": ""
}

brackets_regex = re.compile('\[.*?\]')
apostrophe_regex = re.compile("[']")
punctuation_regex = re.compile('[^0-9a-zA-Z ]+')
double_space_regex = re.compile('\s+')

lyrics = initial_lyrics.lower()
lyrics = brackets_regex.sub("", lyrics)
lyrics = apostrophe_regex.sub("", lyrics)
lyrics = punctuation_regex.sub("", lyrics)
lyrics = double_space_regex.sub(" ", lyrics)

lyrics = lyrics.split()
lyrics = [word for word in lyrics if word in vocabulary]
lyrics = ' '.join(lyrics)

new_data['lyrics_string'] = lyrics
new_data = pd.DataFrame(new_data, index=[len(data)])
data = data.append(new_data)
data
# Out:
#                     artist  cluster  \
# 0                      '68        0
# 1               (sic)monic        1
# 2                      +\-       27
# 3          ...aaaarrghh...       18
# 4            ...and oceans       27
# 5                 .calibre       19
# 6                  .crrust        7
# 7               100 demons       25
# 8            1000 funerals       17
# 9     11 as in adversaries       21
# 10          11th dimension        7
# 11         122 stab wounds       19
# 12                13 faces       25
# 13              13 winters       27
# 14                    1349       16
# 15              13th draft        7
# 16                      16        4
# 17                 16 volt        7
# 18                    1956       19
# 19          2 times terror       19
# 20              25 ta life       22
# 21                  2cents       11
# 22             2nd suicide       27
# 23                     2x4        7
# 24                       3        3
# 25       3 inches of blood       28
# 26           36 crazyfists       11
# 27                3rd room        7
# 28                3rd root       10
# 29             40 watt sun        7
# ...                    ...      ...
# 7405              zerakiel       27
# 7406             zeraphine        3
# 7407           zero cipher        8
# 7408           zero degree       19
# 7409             zero hour        3
# 7410             zerokarma       19
# 7411            zeromancer        7
# 7412         zimmer's hole       14
# 7413                   zix        2
# 7414                 znich       19
# 7415              znowhite        1
# 7416              zoetrope        7
# 7417           zombie inc.       12
# 7418               zonaria        1
# 7419                zonata       23
# 7420             zorakarer        1
# 7421               zozobra       27
# 7422             zubrowska        7
# 7423               zuul fx       22
# 7424               zygnema       22
# 7425                zyklon        1
# 7426               zørormr       17
# 7427               ásmegin       18
# 7428                ænimus        1
# 7429           æther realm        2
# 7430              ætherial        7
# 7431                   íon       27
# 7432            øscillatör       19
# 7433                   new        0
# 7434                   new        0
#
#                                          frequent_words         genre_label  \
# 0     gimme maybe aint hey lying gonna shes class ba...          Glam Metal
# 1     shall existence self control reality fucking m...        Thrash Metal
# 7429  alone ancient mountaintop stood one lost way w...              Epic
# 7430  penitent man pass anymore sinner shall perish ...      Getting Over
# 7431  hear sirens sigh hopes misplaced hearts laid h...  Nature & Sadness
# 7432  recondite motives necessitate reform terrestri...     Cosmic Horror
# 7433  oozing reeks gastric juices melt major arterie...
# 7434  legends ran majesty future defeated evil yearn...
#
#              x         y
# 0    -0.329639  0.565931
# 1    -0.273161 -0.203549
# 2    -0.569364 -0.359816
# 3    -0.810511 -0.245691
# 4    -0.573531  0.149318
# 5    -0.406454  0.613611
# 6    -0.621415  0.141845
# 7    -0.041817 -0.541671
# 8    -0.596968  0.420211
# 9    -0.731733 -0.382420
# 10    0.556636  0.483238
# 11   -0.524738  0.460241
# 12    0.463418 -0.472169
# 13   -0.468721 -0.151959
# 14   -0.143169  0.350102
# 15   -0.646600 -0.354189
# 16    0.215097 -0.423585
# 17    0.345109 -0.631187
# 18    0.462933  0.651626
# 19   -0.722375  0.207902
# 20    0.720883 -0.266474
# 21   -0.263435 -0.450142
# 22   -0.577928  0.291648
# 23    0.569070 -0.462087
# 24   -0.123056 -0.331912
# 25   -0.151240  0.252786
# 26   -0.109164 -0.274419
# 27   -0.023880 -0.787742
# 28    0.285289 -0.677725
# 29    0.585339  0.328697
# ...        ...       ...
# 7405 -0.598369 -0.306544
# 7406 -0.289887 -0.333772
# 7407  0.258095 -0.656182
# 7408  0.675213 -0.244089
# 7409  0.083104  0.057260
# 7410 -0.464429  0.544600
# 7411  0.247529 -0.650047
# 7412 -0.054896 -0.669477
# 7413 -0.388840  0.521003
# 7414 -0.838457 -0.156573
# 7415 -0.548264 -0.119004
# 7416  0.280296 -0.722794
# 7417 -0.491712 -0.401350
# 7418 -0.248839  0.001575
# 7419 -0.170872  0.072421
# 7420  0.705434 -0.008296
# 7421 -0.534902  0.290717
# 7422 -0.413674 -0.602312
# 7423  0.207914 -0.511810
# 7424 -0.457643 -0.330221
# 7425 -0.552790  0.287640
# 7426 -0.395222  0.491889
# 7427 -0.562783  0.627858
# 7428  0.373226  0.582194
# 7429 -0.505631  0.227837
# 7430 -0.394436 -0.499350
# 7431  0.627338 -0.317566
# 7432 -0.764456 -0.105708
# 7433  0.000000  0.000000
# 7434  0.000000  0.000000
#
# [7435 rows x 8 columns]

# %%
vectorizer = TfidfVectorizer(ngram_range=(1, 1), stop_words='english', min_df=25, max_df=0.5)
x = vectorizer.fit_transform(data['lyrics_string'])
features = vectorizer.get_feature_names()
transformed = km.transform(x)
D = euclidean_distances(transformed.getrow(len(data)-1), km.cluster_centers_)
print D
#predictions = km.predict(x)
#predictions

# %%
km.score(x.getrow(len(data)-1))
# Out:
# -1.0053425295369098

# %%
cluster = predictions[-1]
cluster_labels = data[data.cluster == cluster].iloc[0]['frequent_words']
print cluster
print cluster_labels
# Out:
# 19
# shall fucking evil people eternal reality self existence gods escape shadows final control chaos stars minds destruction space endless future sea faith fuck void great grave sight suffering sorrow spirit

# %%
artist_sample = data[(data.cluster == cluster) & (data.artist != 'new')].sample(5)
artist_list = [row['artist'] for i, row in artist_sample.iterrows()]
print artist_list
song_sample = pd.DataFrame()
for i in range(0,5):
    song_sample = song_sample.append(original_data[original_data.artist == artist_list[i]].sample(1))
song_sample.head()
# Out:
# [u'audiomachy', u'maln\xe0tt', u'delusions of godhood', u'perdition', u'ignotus enthropya']
#                      album                artist  \
# 44085       Whoopsy Stabby            audiomachy
# 6974     La Voce Dei Morti               malnàtt
# 73936           Dreamscape  delusions of godhood
# 2099   This Wretched World             perdition
# 3675          Solid Silver     ignotus enthropya
#
#                                 name  year  \
# 44085                  Oscillicision  2011
# 6974                I Felt A Funeral  2008
# 73936  Through The Jaws Of Perdition  2015
# 2099                     The Village  2012
# 3675                      Extinction  2014
#
#                                                   lyrics
# 44085  [Various things were said but I don't think th...
# 6974   [[Lyrics by Emily Dickinson], I felt a funeral...
# 73936  [[feat. Urban Granbacke], Beyond this mortal c...
# 2099   [Bring unto them their worst, They stand toget...
# 3675   [A world full of people, Crowded and diseased ...

# %%
resulting_dict = song_sample.to_dict(orient='index')
resulting_dict
# Out:
# {2099: {u'album': u'This Wretched World',
#   u'artist': u'perdition',
#   'lyrics': [u'Bring unto them their worst',
#    u'They stand together as one of their brotherhood',
#    u'Fed from the food of their morals',
#    u'Colonized and accepted ideals raised into society',
#    u'A matter of time is only needed:',
#    u'The village will collapse upon itself, a twisted colony of beautiful perfection ',
#    u'[2x]',
#    u'Corrupt by fake ideals and a faux path to safety ',
#    u'[2x]',
#    u'The village will bring destruction, branching outward towards every last crevice of the earth',
#    u'How can you justify this? ',
#    u'[2x]',
#    u'The disgust of ego married with arrogance dressed in white',
#    u'A grotesque picture praised by the village like a false idol',
#    u'The village will bring violence',
#    u'Violence will bring destruction',
#    u'Destruction will bring your end',
#    u'The village is you, composed of your ideals, composed of your lies',
#    u'Composed of your ideals, composed of your lies...',
#    u'Bring forth the depths, swallow this village whole.'],
#   u'name': u'The Village',
#   u'year': 2012},
#  3675: {u'album': u'Solid Silver',
#   u'artist': u'ignotus enthropya',
#   'lyrics': [u'A world full of people',
#    u'Crowded and diseased by',
#    u'A race so arrogant',
#    u'Of self-proclaimed knights',
#    u'As we fall',
#    u"We don't realise",
#    u'(What is wrong)',
#    u'Without knowing ',
#    u'We stand mesmerized',
#    u'Where are the answers',
#    u'For our demise?',
#    u'A world full of hatred',
#    u'Destroyed and poisoned by',
#    u'A race so arrogant',
#    u'Of self-proclaimed gods',
#    u'People are always claiming',
#    u"They're conquering, never sharing",
#    u"Caring 's so scarce",
#    u'Unmeasured sacrifice',
#    u'As we fall',
#    u"We don't realise",
#    u'(What is wrong)',
#    u'Without knowing ',
#    u'We stand mesmerized',
#    u'We never recognized',
#    u"We're not the only ones",
#    u'If we keep our ways',
#    u'Our world will die',
#    u'The people surrendered',
#    u'Helpless and ashamed',
#    u'If we do not change',
#    u'Everyone dies',
#    u'Conflicts are always rising',
#    u'Fights are most exciting',
#    u'Violence grows',
#    u'The prices are unknown',
#    u'As we fall',
#    u"We don't realise",
#    u'(What is wrong)',
#    u'Without knowing ',
#    u'We stand mesmerized'],
#   u'name': u'Extinction',
#   u'year': 2014},
#  6974: {u'album': u'La Voce Dei Morti',
#   u'artist': u'maln\xe0tt',
#   'lyrics': [u'[Lyrics by Emily Dickinson]',
#    u'I felt a funeral in my brain,',
#    u'And mourners, to and fro,',
#    u'Kept treading, treading, till it seemed',
#    u'That sense was breaking through.',
#    u'And when they all were seated,',
#    u'A service like a drum',
#    u'Kept beating, beating, till I thought',
#    u'My mind was going numb.',
#    u'And then I heard them lift a box,',
#    u'And creak across my soul',
#    u'With those same boots of lead, (again)',
#    u'Then space began to toll',
#    u'As all the heavens were a bell,',
#    u'And Being but an ear,',
#    u'And I and silence some strange race,',
#    u'Wrecked, solitary, here.',
#    u'And then a plank in reason, broke,',
#    u'And I dropped down and down',
#    u'And hit a world at every plunge,',
#    u'And finished knowing -then-'],
#   u'name': u'I Felt A Funeral',
#   u'year': 2008},
#  44085: {u'album': u'Whoopsy Stabby',
#   u'artist': u'audiomachy',
#   'lyrics': [u"Various things were said but I don't think they'll regain consciousness",
#    u'after that veritable bubble bath of mind games',
#    u'Regaling in light of the events that transpired',
#    u'think not of the grenade that affected our fiscal stability',
#    u'those things are expensive you know',
#    u'Unable to break free of the iron clad carapace dependency',
#    u'I may be experiencing a seizure',
#    u'Oh a free jacket why do the sleeves have locks?',
#    u'Resulting in my eventual desire',
#    u'to startup a interperceptually challenged arboretum clause',
#    u'Forged from the charred remains of that',
#    u'ludicrously oversized golden ethereal foam finger',
#    u'And now ladies and gentlemen we present a breakdown with the wrong instrument',
#    u'Ahh, it followed me home',
#    u'the black and white dentigerous wooden frame',
#    u'Haunts my discordant disarray',
#    u'with its hidden organized melodic string accumulation',
#    u'Aww, you\u2019re such a di -.. .. -.-. -.-',
#    u'The lobotomy had better come quickly',
#    u'I can\u2019t stand the sight of needy eyes',
#    u'I need to hide the mind intestine',
#    u'Seriously it looks like an organised intestine',
#    u'I\u2019ve seen how they look at me',
#    u'Jealous of protection against the mindreading thieves',
#    u'Be wary of any lurking genies',
#    u'and various other precious common thoughts.'],
#   u'name': u'Oscillicision',
#   u'year': 2011},
#  73936: {u'album': u'Dreamscape',
#   u'artist': u'delusions of godhood',
#   'lyrics': [u'[feat. Urban Granbacke]',
#    u'Beyond this mortal coil',
#    u'Beyond the realm of man',
#    u'Into the abyss',
#    u'This godforsaken land',
#    u'Tainted, rancid souls',
#    u'Roam this plane of damned',
#    u'Banished, by your God',
#    u'Where\u2019s your savior now?',
#    u'Parish',
#    u'Torture',
#    u'Anguish',
#    u'Molest',
#    u'Defile',
#    u'Suffer',
#    u'Torn, from the light',
#    u'Consumed by the dark',
#    u'Infernal treachery',
#    u'Through this immortal plight',
#    u'Into the flames',
#    u'Your spirit, eternal burned',
#    u'Scorch, melted, ripped from flesh',
#    u'Affliction evermore',
#    u'You broke His laws',
#    u'Now thrown into',
#    u'The jaws of Hell',
#    u'Unrest in discord',
#    u'Now cast into',
#    u'The mouth of fire',
#    u'And brimstone you feel',
#    u'Slaughter of the Soul!',
#    u'Torn, from the light',
#    u'Consumed by the dark',
#    u'Infernal treachery',
#    u'Through this immortal plight',
#    u'Into the flames',
#    u'Your spirit, eternal burned',
#    u'Scorch, melted, ripped from flesh',
#    u'Affliction evermore',
#    u'Torn, from the light',
#    u'Consumed by the dark',
#    u'Infernal treachery',
#    u'Through this immortal plight',
#    u'Into the flames',
#    u'Your spirit, eternal burned',
#    u'Scorch, melted, ripped from flesh',
#    u'Affliction evermore'],
#   u'name': u'Through The Jaws Of Perdition',
#   u'year': 2015}}
